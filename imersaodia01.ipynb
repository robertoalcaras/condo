# %% [markdown]
# <a href="https://colab.research.google.com/github/robertoalcaras/condo/blob/master/imersaodia01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Roberto de Lima Alcaras

# %%
import pandas as pd

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression= 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize =True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize =True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ### desafio 01: Investiga o porque a classe tratamento é tão desbanlanceada?
# ### desafio 02: Como plotar as cinco ultimas linha do dataframe ou tabela?
# ### desafio 03: porporção das classes tratamento.
# ### desabio 04: Quantas tipos de drovas foram invetigados.
# ### desafio 05: Procurar na documentação o método query(pandas).
# ### desafio 06: Renomear as colunas tirando o hífen.
# ### desafio 07: titulo no grafico de barras(bonitões).(matplotlib.pyplot
# ### desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# ###desafio 01: Investiga o porque a classe tratamento é tão desbanlanceada?

# %% [markdown]
# O grupo controle pode ter recebido uma droga que podemos dizer que seja um tipo de placebo, algum produto que essas células deveriam se multiplicar com velocidades menores ou maiores (não sabemos ainda), os produtos que receberam as outras drogas, pegado as 3 primeiras drogas eles tem uma amostra de entre 6 e 7 itens em cada amostra, sendo assim as amostra com_drogas for separadas por tipos de drogas são menores que as com_comtrole, se levar um conta os tipos de drogas (b68db1d53, df89a8e5a, 18bb41b2c),
# A com_controle tem varção de quantidade drogas bem diferenciadas.
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#
#
#
# ---

# %%
dados.query('tratamento == "com_controle"' )
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47     id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63     id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  com_controle     24   D1  ...  0.2131 -0.1419 -0.2422  0.0457
# 23747  id_ff469c482  com_controle     72   D1  ... -0.9630  0.8872 -0.0742 -0.6777
# 23768  id_ff89331ca  com_controle     72   D2  ...  0.9517 -0.8110 -0.1748 -0.3626
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# ...

# %%
dados.query('tratamento == "com_droga"' )
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %%
dados.query('droga == "b68db1d53"' )
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 6175   id_4257c8753  com_droga     48   D2  ...  0.5498  0.5549  0.7475  0.8182
# 13774  id_948ea9d02  com_droga     48   D1  ... -0.2858  0.2747 -0.0332  0.3551
# 14257  id_997d9f25d  com_droga     72   D2  ...  0.7134 -0.4061  0.6136 -0.3192
# 20190  id_d8c3cebd1  com_droga     24   D2  ...  0.1703  0.3615  1.1420  0.9481
# 22507  id_f1c7f3184  com_droga     72   D1  ...  1.9420  0.9040  0.3415  0.6709
#
# [6 rows x 877 columns]

# %%
dados.query('droga == "df89a8e5a"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 5389   id_3a1a0a94a  com_droga     24   D2  ...  0.5564  0.1029 -0.1804  0.1189
# 6070   id_416ba6804  com_droga     24   D1  ...  0.9396 -0.1500  0.5778 -0.8005
# 12328  id_84cfb2d4e  com_droga     48   D2  ...  1.1490  0.9931 -0.5764  0.1321
# 14089  id_97b32c381  com_droga     48   D1  ...  0.2351 -0.1712  0.7836  0.2187
# 19987  id_d6421128d  com_droga     72   D2  ... -0.2848  0.1784 -0.0047 -0.5186
#
# [6 rows x 877 columns]

# %%
dados.query('droga == "18bb41b2c"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3590   id_26851f3cd  com_droga     48   D1  ... -0.1113  0.3835 -1.9490  0.6036
# 3911   id_29cf61b5b  com_droga     48   D2  ...  0.0155 -0.8263 -2.2630  0.7307
# 8457   id_5b0e3aedc  com_droga     72   D2  ...  0.3250 -0.4199 -1.5100  0.0848
# 11030  id_76b464684  com_droga     72   D1  ...  0.0477  0.7266 -2.9180  0.2656
# 14446  id_9b94f2c9c  com_droga     24   D2  ... -0.0859 -0.0859  0.4082  0.2391
# 15218  id_a37496f52  com_droga     24   D1  ... -0.8838  0.0869 -1.3620 -0.6811
#
# [7 rows x 877 columns]

# %% [markdown]
# ### desafio 02: Como plotar as cinco ultimas linha do dataframe ou tabela?

# %%
dados.tail(5)
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ### desafio 03: porporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize =True)*100
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %% [markdown]
# ###desafio 04: Quantas tipos de drogas foram invetigados.
#
# ###total de drogas = 3289

# %%
tipo_de_drogas = dados['droga'].value_counts()
tipo_de_drogas

tipo_de_drogas2 = pd.DataFrame(tipo_de_drogas)
tipo_de_drogas2
# Out:
#            droga
# cacb2b860   1866
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# ...          ...
# 27fa72002      1
# 42feaa183      1
# 1502f8cbb      1
# f5c443039      1
# ede646bcc      1
#
# [3289 rows x 1 columns]

# %% [markdown]
# ###

# %% [markdown]
# ### desafio 05: Procurar na documentação o método query(pandas).

# %%
dados.query('droga == "18bb41b2c"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 2      id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3590   id_26851f3cd  com_droga     48   D1  ... -0.1113  0.3835 -1.9490  0.6036
# 3911   id_29cf61b5b  com_droga     48   D2  ...  0.0155 -0.8263 -2.2630  0.7307
# 8457   id_5b0e3aedc  com_droga     72   D2  ...  0.3250 -0.4199 -1.5100  0.0848
# 11030  id_76b464684  com_droga     72   D1  ...  0.0477  0.7266 -2.9180  0.2656
# 14446  id_9b94f2c9c  com_droga     24   D2  ... -0.0859 -0.0859  0.4082  0.2391
# 15218  id_a37496f52  com_droga     24   D1  ... -0.8838  0.0869 -1.3620 -0.6811
#
# [7 rows x 877 columns]

# %% [markdown]
# ###desafio 06: Renomear as colunas tirando o hífen.

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
df = pd.read_csv(url_dados, compression= 'zip')
df

df.columns = df.columns.str.lower().str.replace('-', '')

# %%
df
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
df
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###desafio 07: titulo no grafico de barras(bonitões).(matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
dados['tempo'].value_counts().plot.bar()
plt.title("Amostras com o Devido Quantidade X Tempo ")
plt.xlabel("Quantidade de Horas")
plt.ylabel("Quantidade Amostras")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### desafio 08: Resumo do que você aprendeu com os dados.
#
# Verificando os dados cheguei a conclusão que tratamento com_droga e com_controle, as drogas são divididas em quantidade diferenciadas para cada um dos itens do dataframe, precisando de uma melhor direfencia entre os outros item como g e c do dataframe para chegar a uma conclusão
